# %% [markdown]
# ## **プログラム全体の流れ**
# - データローダの作成
# - ネットワークの定義
# - 誤差関数の定義
# - 学習ループの設計
# - モデルの学習
# - モデルの評価

# %% [markdown]
# # k-fold cross validationの仕組みを作っておく

# %% [markdown]
# - negative(165), positive(55)が混ざるようにしたい\
# →別々で分割して，結合する
# - 時期も混ざるようにしたい\
# →症例でシャッフルしてから分割する

# %%
import glob
from sklearn.model_selection import KFold

# %%
# 症例リストを取り出す
neg = glob.glob("dataset/PAS_imgs/negative/*")
pos = glob.glob("dataset/PAS_imgs/positive/*")

# %%
def make_kfold_set(k):
    k = k

    kf = KFold(n_splits=k, shuffle=True)

    neg_train_test_list = []
    pos_train_test_list = []

    for train_index, test_index in kf.split(neg):
        kth_train = []
        kth_test = []
        for i in train_index:
            kth_train.append(neg[i])
        for i in test_index:
            kth_test.append(neg[i])
        neg_train_test_list.append((kth_train, kth_test))

    for train_index, test_index in kf.split(pos):
        kth_train = []
        kth_test = []
        for i in train_index:
            kth_train.append(pos[i])
        for i in test_index:
            kth_test.append(pos[i])
        pos_train_test_list.append((kth_train, kth_test))


    posneg_train_test_list = []

    for i in range(k):
        train = pos_train_test_list[i][0] + neg_train_test_list[i][0]
        test = pos_train_test_list[i][1] + neg_train_test_list[i][1]
        posneg_train_test_list.append((train, test))

    
    return posneg_train_test_list

# %% [markdown]
# <div style="text-align: center;">
# <IMG SRC="https://drive.google.com/uc?id=1rWgWkMT0LLv17p21C2NQMjPh_bkJ_Fcu" width="70%">
# <br>
# 図5　ミニバッチ学習のおさらい
# </div>

# %% [markdown]
# ## データセットクラスを作る

# %%
import numpy as np
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
# クラスのわかりやすい例
class Human:
    def __init__(self):
        self.arms = 2
        self.legs = 2
    
    def walk(self):
        print("walking!")

# %%
class Takaya(Human):
    def __init__(self):
        super().__init__()
        self.hair = "curl"
    
    def program(self):
        print("coding!")

# %%
bob.walk()
# Out:
# walking!

# %%
takaya = Takaya() # インスタンス化

# %%
class PASDataset(Dataset):
    def __init__(self, kfold_list, fold_index):
        super().__init__()
        # 呼び出された瞬間に起こってほしいこと（コンストラクタ）
        self.k_train_test_list = make_kfold_set(k)
    
    def __len__(self):
        # データがいくつあるのかを数える
        return
    
    
    def __getitem__(self, index):
        # データが取り出される瞬間にどのような形であってほしいかを定義する
        image_path = self.k_train_test_list[index]
        
        return img

# %%
k = 5
kfold_list = make_kfold_set(k)

for i in range(5):
    PAS = PASDataset(ith_fold)
    predict = model(PAS)

# %%
len(PAS)
# Out:
# [(['dataset/PAS_imgs/positive/1029',
#    'dataset/PAS_imgs/positive/1015',
#    'dataset/PAS_imgs/positive/1016',
#    'dataset/PAS_imgs/positive/1017',
#    'dataset/PAS_imgs/positive/1012',
#    'dataset/PAS_imgs/positive/1038',
#    'dataset/PAS_imgs/positive/1039',
#    'dataset/PAS_imgs/positive/1011',
#    'dataset/PAS_imgs/positive/1049',
#    'dataset/PAS_imgs/positive/1048',
#    'dataset/PAS_imgs/positive/1043',
#    'dataset/PAS_imgs/positive/1057',
#    'dataset/PAS_imgs/positive/1056',
#    'dataset/PAS_imgs/positive/1054',
#    'dataset/PAS_imgs/positive/1040',
#    'dataset/PAS_imgs/positive/1041',
#    'dataset/PAS_imgs/positive/1051',
#    'dataset/PAS_imgs/positive/1045',
#    'dataset/PAS_imgs/positive/1044',
#    'dataset/PAS_imgs/positive/1050',
#    'dataset/PAS_imgs/positive/1046',
#    'dataset/PAS_imgs/positive/1052',
#    'dataset/PAS_imgs/positive/1053',
#    'dataset/PAS_imgs/positive/1047',
#    'dataset/PAS_imgs/positive/1020',
#    'dataset/PAS_imgs/positive/1035',
#    'dataset/PAS_imgs/positive/1009',
#    'dataset/PAS_imgs/positive/1023',
#    'dataset/PAS_imgs/positive/1032',
#    'dataset/PAS_imgs/positive/1027',
#    'dataset/PAS_imgs/positive/1033',
#    'dataset/PAS_imgs/positive/1025',
#    'dataset/PAS_imgs/positive/1031',
#    'dataset/PAS_imgs/positive/1019',
#    'dataset/PAS_imgs/positive/1018',
#    'dataset/PAS_imgs/positive/1030',
#    'dataset/PAS_imgs/positive/1024',
#    'dataset/PAS_imgs/negative/7048',
#    'dataset/PAS_imgs/negative/7060',
#    'dataset/PAS_imgs/negative/7074',
#    'dataset/PAS_imgs/negative/7128',
#    'dataset/PAS_imgs/negative/7114',
#    'dataset/PAS_imgs/negative/7100',
#    'dataset/PAS_imgs/negative/7101',
#    'dataset/PAS_imgs/negative/7129',
#    'dataset/PAS_imgs/negative/7049',
#    'dataset/PAS_imgs/negative/7077',
#    'dataset/PAS_imgs/negative/7088',
#    'dataset/PAS_imgs/negative/7103',
#    'dataset/PAS_imgs/negative/7117',
#    'dataset/PAS_imgs/negative/7116',
#    'dataset/PAS_imgs/negative/7102',
#    'dataset/PAS_imgs/negative/7089',
#    'dataset/PAS_imgs/negative/7062',
#    'dataset/PAS_imgs/negative/7066',
#    'dataset/PAS_imgs/negative/7099',
#    'dataset/PAS_imgs/negative/7106',
#    'dataset/PAS_imgs/negative/7112',
#    'dataset/PAS_imgs/negative/7113',
#    'dataset/PAS_imgs/negative/7107',
#    'dataset/PAS_imgs/negative/7098',
#    'dataset/PAS_imgs/negative/7067',
#    'dataset/PAS_imgs/negative/7065',
#    'dataset/PAS_imgs/negative/7111',
#    'dataset/PAS_imgs/negative/7105',
#    'dataset/PAS_imgs/negative/7110',
#    'dataset/PAS_imgs/negative/7058',
#    'dataset/PAS_imgs/negative/7003',
#    'dataset/PAS_imgs/negative/7017',
#    'dataset/PAS_imgs/negative/7002',
#    'dataset/PAS_imgs/negative/7028',
#    'dataset/PAS_imgs/negative/7014',
#    'dataset/PAS_imgs/negative/7001',
#    'dataset/PAS_imgs/negative/7015',
#    'dataset/PAS_imgs/negative/7011',
#    'dataset/PAS_imgs/negative/7039',
#    'dataset/PAS_imgs/negative/7038',
#    'dataset/PAS_imgs/negative/7004',
#    'dataset/PAS_imgs/negative/7010',
#    'dataset/PAS_imgs/negative/7006',
#    'dataset/PAS_imgs/negative/7012',
#    'dataset/PAS_imgs/negative/7013',
#    'dataset/PAS_imgs/negative/7007',
#    'dataset/PAS_imgs/negative/7036',
#    'dataset/PAS_imgs/negative/7023',
#    'dataset/PAS_imgs/negative/7009',
#    'dataset/PAS_imgs/negative/7035',
#    'dataset/PAS_imgs/negative/7021',
#    'dataset/PAS_imgs/negative/7020',
#    'dataset/PAS_imgs/negative/7008',
#    'dataset/PAS_imgs/negative/7030',
#    'dataset/PAS_imgs/negative/7024',
#    'dataset/PAS_imgs/negative/7018',
#    'dataset/PAS_imgs/negative/7025',
#    'dataset/PAS_imgs/negative/7031',
#    'dataset/PAS_imgs/negative/7027',
#    'dataset/PAS_imgs/negative/7033',
#    'dataset/PAS_imgs/negative/7032',
#    'dataset/PAS_imgs/negative/7026',
#    'dataset/PAS_imgs/negative/7041',
#    'dataset/PAS_imgs/negative/7055',
#    'dataset/PAS_imgs/negative/7109',
#    'dataset/PAS_imgs/negative/7135',
#    'dataset/PAS_imgs/negative/7121',
#    'dataset/PAS_imgs/negative/7120',
#    'dataset/PAS_imgs/negative/7134',
#    'dataset/PAS_imgs/negative/7108',
#    'dataset/PAS_imgs/negative/7097',
#    'dataset/PAS_imgs/negative/7083',
#    'dataset/PAS_imgs/negative/7054',
#    'dataset/PAS_imgs/negative/7040',
#    'dataset/PAS_imgs/negative/7068',
#    'dataset/PAS_imgs/negative/7056',
#    'dataset/PAS_imgs/negative/7042',
#    'dataset/PAS_imgs/negative/7095',
#    'dataset/PAS_imgs/negative/7122',
#    'dataset/PAS_imgs/negative/7136',
#    'dataset/PAS_imgs/negative/7080',
#    'dataset/PAS_imgs/negative/7094',
#    'dataset/PAS_imgs/negative/7043',
#    'dataset/PAS_imgs/negative/7053',
#    'dataset/PAS_imgs/negative/7047',
#    'dataset/PAS_imgs/negative/7090',
#    'dataset/PAS_imgs/negative/7084',
#    'dataset/PAS_imgs/negative/7133',
#    'dataset/PAS_imgs/negative/7132',
#    'dataset/PAS_imgs/negative/7126',
#    'dataset/PAS_imgs/negative/7085',
#    'dataset/PAS_imgs/negative/7091',
#    'dataset/PAS_imgs/negative/7046',
#    'dataset/PAS_imgs/negative/7052',
#    'dataset/PAS_imgs/negative/7044',
#    'dataset/PAS_imgs/negative/7050',
#    'dataset/PAS_imgs/negative/7078',
#    'dataset/PAS_imgs/negative/7087',
#    'dataset/PAS_imgs/negative/7093',
#    'dataset/PAS_imgs/negative/7130',
#    'dataset/PAS_imgs/negative/7124',
#    'dataset/PAS_imgs/negative/7118',
#    'dataset/PAS_imgs/negative/7125',
#    'dataset/PAS_imgs/negative/7131',
#    'dataset/PAS_imgs/negative/7086',
#    'dataset/PAS_imgs/negative/7079',
#    'dataset/PAS_imgs/negative/7051',
#    'dataset/PAS_imgs/negative/7045'],
#   ['dataset/PAS_imgs/positive/1028',
#    'dataset/PAS_imgs/positive/1013',
#    'dataset/PAS_imgs/positive/1010',
#    'dataset/PAS_imgs/positive/1055',
#    'dataset/PAS_imgs/positive/1034',
#    'dataset/PAS_imgs/positive/1021',
#    'dataset/PAS_imgs/positive/1037',
#    'dataset/PAS_imgs/positive/1022',
#    'dataset/PAS_imgs/positive/1036',
#    'dataset/PAS_imgs/positive/1026',
#    'dataset/PAS_imgs/negative/7115',
#    'dataset/PAS_imgs/negative/7075',
#    'dataset/PAS_imgs/negative/7061',
#    'dataset/PAS_imgs/negative/7063',
#    'dataset/PAS_imgs/negative/7076',
#    'dataset/PAS_imgs/negative/7072',
#    'dataset/PAS_imgs/negative/7073',
#    'dataset/PAS_imgs/negative/7071',
#    'dataset/PAS_imgs/negative/7059',
#    'dataset/PAS_imgs/negative/7104',
#    'dataset/PAS_imgs/negative/7070',
#    'dataset/PAS_imgs/negative/7064',
#    'dataset/PAS_imgs/negative/7016',
#    'dataset/PAS_imgs/negative/7029',
#    'dataset/PAS_imgs/negative/7005',
#    'dataset/PAS_imgs/negative/7022',
#    'dataset/PAS_imgs/negative/7037',
#    'dataset/PAS_imgs/negative/7034',
#    'dataset/PAS_imgs/negative/7019',
#    'dataset/PAS_imgs/negative/7069',
#    'dataset/PAS_imgs/negative/7082',
#    'dataset/PAS_imgs/negative/7096',
#    'dataset/PAS_imgs/negative/7081',
#    'dataset/PAS_imgs/negative/7123',
#    'dataset/PAS_imgs/negative/7057',
#    'dataset/PAS_imgs/negative/7119',
#    'dataset/PAS_imgs/negative/7092']),
#  (['dataset/PAS_imgs/positive/1029',
#    'dataset/PAS_imgs/positive/1015',
#    'dataset/PAS_imgs/positive/1028',
#    'dataset/PAS_imgs/positive/1017',
#    'dataset/PAS_imgs/positive/1013',
#    'dataset/PAS_imgs/positive/1010',
#    'dataset/PAS_imgs/positive/1038',
#    'dataset/PAS_imgs/positive/1039',
#    'dataset/PAS_imgs/positive/1011',
#    'dataset/PAS_imgs/positive/1048',
#    'dataset/PAS_imgs/positive/1043',
#    'dataset/PAS_imgs/positive/1056',
#    'dataset/PAS_imgs/positive/1054',
#    'dataset/PAS_imgs/positive/1040',
#    'dataset/PAS_imgs/positive/1041',
#    'dataset/PAS_imgs/positive/1055',
#    'dataset/PAS_imgs/positive/1051',
#    'dataset/PAS_imgs/positive/1050',
#    'dataset/PAS_imgs/positive/1046',
#    'dataset/PAS_imgs/positive/1052',
#    'dataset/PAS_imgs/positive/1020',
#    'dataset/PAS_imgs/positive/1034',
#    'dataset/PAS_imgs/positive/1021',
#    'dataset/PAS_imgs/positive/1009',
#    'dataset/PAS_imgs/positive/1037',
#    'dataset/PAS_imgs/positive/1023',
#    'dataset/PAS_imgs/positive/1022',
#    'dataset/PAS_imgs/positive/1036',
#    'dataset/PAS_imgs/positive/1032',
#    'dataset/PAS_imgs/positive/1026',
#    'dataset/PAS_imgs/positive/1027',
#    'dataset/PAS_imgs/positive/1033',
#    'dataset/PAS_imgs/positive/1025',
#    'dataset/PAS_imgs/positive/1031',
#    'dataset/PAS_imgs/positive/1019',
#    'dataset/PAS_imgs/positive/1030',
#    'dataset/PAS_imgs/positive/1024',
#    'dataset/PAS_imgs/negative/7048',
#    'dataset/PAS_imgs/negative/7060',
#    'dataset/PAS_imgs/negative/7074',
#    'dataset/PAS_imgs/negative/7128',
#    'dataset/PAS_imgs/negative/7100',
#    'dataset/PAS_imgs/negative/7101',
#    'dataset/PAS_imgs/negative/7115',
#    'dataset/PAS_imgs/negative/7129',
#    'dataset/PAS_imgs/negative/7075',
#    'dataset/PAS_imgs/negative/7061',
#    'dataset/PAS_imgs/negative/7049',
#    'dataset/PAS_imgs/negative/7077',
#    'dataset/PAS_imgs/negative/7063',
#    'dataset/PAS_imgs/negative/7088',
#    'dataset/PAS_imgs/negative/7117',
#    'dataset/PAS_imgs/negative/7116',
#    'dataset/PAS_imgs/negative/7102',
#    'dataset/PAS_imgs/negative/7089',
#    'dataset/PAS_imgs/negative/7062',
#    'dataset/PAS_imgs/negative/7076',
#    'dataset/PAS_imgs/negative/7072',
#    'dataset/PAS_imgs/negative/7066',
#    'dataset/PAS_imgs/negative/7099',
#    'dataset/PAS_imgs/negative/7113',
#    'dataset/PAS_imgs/negative/7107',
#    'dataset/PAS_imgs/negative/7098',
#    'dataset/PAS_imgs/negative/7067',
#    'dataset/PAS_imgs/negative/7073',
#    'dataset/PAS_imgs/negative/7071',
#    'dataset/PAS_imgs/negative/7059',
#    'dataset/PAS_imgs/negative/7111',
#    'dataset/PAS_imgs/negative/7105',
#    'dataset/PAS_imgs/negative/7104',
#    'dataset/PAS_imgs/negative/7110',
#    'dataset/PAS_imgs/negative/7058',
#    'dataset/PAS_imgs/negative/7070',
#    'dataset/PAS_imgs/negative/7064',
#    'dataset/PAS_imgs/negative/7003',
#    'dataset/PAS_imgs/negative/7017',
#    'dataset/PAS_imgs/negative/7016',
#    'dataset/PAS_imgs/negative/7028',
#    'dataset/PAS_imgs/negative/7014',
#    'dataset/PAS_imgs/negative/7001',
#    'dataset/PAS_imgs/negative/7015',
#    'dataset/PAS_imgs/negative/7029',
#    'dataset/PAS_imgs/negative/7011',
#    'dataset/PAS_imgs/negative/7005',
#    'dataset/PAS_imgs/negative/7039',
#    'dataset/PAS_imgs/negative/7010',
#    'dataset/PAS_imgs/negative/7006',
#    'dataset/PAS_imgs/negative/7012',
#    'dataset/PAS_imgs/negative/7022',
#    'dataset/PAS_imgs/negative/7036',
#    'dataset/PAS_imgs/negative/7037',
#    'dataset/PAS_imgs/negative/7009',
#    'dataset/PAS_imgs/negative/7035',
#    'dataset/PAS_imgs/negative/7021',
#    'dataset/PAS_imgs/negative/7020',
#    'dataset/PAS_imgs/negative/7034',
#    'dataset/PAS_imgs/negative/7024',
#    'dataset/PAS_imgs/negative/7018',
#    'dataset/PAS_imgs/negative/7019',
#    'dataset/PAS_imgs/negative/7031',
#    'dataset/PAS_imgs/negative/7032',
#    'dataset/PAS_imgs/negative/7069',
#    'dataset/PAS_imgs/negative/7041',
#    'dataset/PAS_imgs/negative/7055',
#    'dataset/PAS_imgs/negative/7082',
#    'dataset/PAS_imgs/negative/7096',
#    'dataset/PAS_imgs/negative/7109',
#    'dataset/PAS_imgs/negative/7135',
#    'dataset/PAS_imgs/negative/7120',
#    'dataset/PAS_imgs/negative/7108',
#    'dataset/PAS_imgs/negative/7097',
#    'dataset/PAS_imgs/negative/7054',
#    'dataset/PAS_imgs/negative/7040',
#    'dataset/PAS_imgs/negative/7068',
#    'dataset/PAS_imgs/negative/7042',
#    'dataset/PAS_imgs/negative/7095',
#    'dataset/PAS_imgs/negative/7081',
#    'dataset/PAS_imgs/negative/7122',
#    'dataset/PAS_imgs/negative/7136',
#    'dataset/PAS_imgs/negative/7123',
#    'dataset/PAS_imgs/negative/7094',
#    'dataset/PAS_imgs/negative/7057',
#    'dataset/PAS_imgs/negative/7053',
#    'dataset/PAS_imgs/negative/7047',
#    'dataset/PAS_imgs/negative/7090',
#    'dataset/PAS_imgs/negative/7084',
#    'dataset/PAS_imgs/negative/7133',
#    'dataset/PAS_imgs/negative/7132',
#    'dataset/PAS_imgs/negative/7126',
#    'dataset/PAS_imgs/negative/7085',
#    'dataset/PAS_imgs/negative/7091',
#    'dataset/PAS_imgs/negative/7046',
#    'dataset/PAS_imgs/negative/7052',
#    'dataset/PAS_imgs/negative/7050',
#    'dataset/PAS_imgs/negative/7078',
#    'dataset/PAS_imgs/negative/7130',
#    'dataset/PAS_imgs/negative/7124',
#    'dataset/PAS_imgs/negative/7118',
#    'dataset/PAS_imgs/negative/7119',
#    'dataset/PAS_imgs/negative/7131',
#    'dataset/PAS_imgs/negative/7092',
#    'dataset/PAS_imgs/negative/7086',
#    'dataset/PAS_imgs/negative/7079',
#    'dataset/PAS_imgs/negative/7051',
#    'dataset/PAS_imgs/negative/7045'],
#   ['dataset/PAS_imgs/positive/1016',
#    'dataset/PAS_imgs/positive/1012',
#    'dataset/PAS_imgs/positive/1049',
#    'dataset/PAS_imgs/positive/1057',
#    'dataset/PAS_imgs/positive/1045',
#    'dataset/PAS_imgs/positive/1044',
#    'dataset/PAS_imgs/positive/1053',
#    'dataset/PAS_imgs/positive/1047',
#    'dataset/PAS_imgs/positive/1035',
#    'dataset/PAS_imgs/positive/1018',
#    'dataset/PAS_imgs/negative/7114',
#    'dataset/PAS_imgs/negative/7103',
#    'dataset/PAS_imgs/negative/7106',
#    'dataset/PAS_imgs/negative/7112',
#    'dataset/PAS_imgs/negative/7065',
#    'dataset/PAS_imgs/negative/7002',
#    'dataset/PAS_imgs/negative/7038',
#    'dataset/PAS_imgs/negative/7004',
#    'dataset/PAS_imgs/negative/7013',
#    'dataset/PAS_imgs/negative/7007',
#    'dataset/PAS_imgs/negative/7023',
#    'dataset/PAS_imgs/negative/7008',
#    'dataset/PAS_imgs/negative/7030',
#    'dataset/PAS_imgs/negative/7025',
#    'dataset/PAS_imgs/negative/7027',
#    'dataset/PAS_imgs/negative/7033',
#    'dataset/PAS_imgs/negative/7026',
#    'dataset/PAS_imgs/negative/7121',
#    'dataset/PAS_imgs/negative/7134',
#    'dataset/PAS_imgs/negative/7083',
#    'dataset/PAS_imgs/negative/7056',
#    'dataset/PAS_imgs/negative/7080',
#    'dataset/PAS_imgs/negative/7043',
#    'dataset/PAS_imgs/negative/7044',
#    'dataset/PAS_imgs/negative/7087',
#    'dataset/PAS_imgs/negative/7093',
#    'dataset/PAS_imgs/negative/7125']),
#  (['dataset/PAS_imgs/positive/1029',
#    'dataset/PAS_imgs/positive/1015',
#    'dataset/PAS_imgs/positive/1028',
#    'dataset/PAS_imgs/positive/1016',
#    'dataset/PAS_imgs/positive/1013',
#    'dataset/PAS_imgs/positive/1012',
#    'dataset/PAS_imgs/positive/1010',
#    'dataset/PAS_imgs/positive/1049',
#    'dataset/PAS_imgs/positive/1048',
#    'dataset/PAS_imgs/positive/1043',
#    'dataset/PAS_imgs/positive/1057',
#    'dataset/PAS_imgs/positive/1056',
#    'dataset/PAS_imgs/positive/1054',
#    'dataset/PAS_imgs/positive/1040',
#    'dataset/PAS_imgs/positive/1041',
#    'dataset/PAS_imgs/positive/1055',
#    'dataset/PAS_imgs/positive/1051',
#    'dataset/PAS_imgs/positive/1045',
#    'dataset/PAS_imgs/positive/1044',
#    'dataset/PAS_imgs/positive/1050',
#    'dataset/PAS_imgs/positive/1046',
#    'dataset/PAS_imgs/positive/1053',
#    'dataset/PAS_imgs/positive/1047',
#    'dataset/PAS_imgs/positive/1020',
#    'dataset/PAS_imgs/positive/1034',
#    'dataset/PAS_imgs/positive/1035',
#    'dataset/PAS_imgs/positive/1021',
#    'dataset/PAS_imgs/positive/1009',
#    'dataset/PAS_imgs/positive/1037',
#    'dataset/PAS_imgs/positive/1022',
#    'dataset/PAS_imgs/positive/1036',
#    'dataset/PAS_imgs/positive/1032',
#    'dataset/PAS_imgs/positive/1026',
#    'dataset/PAS_imgs/positive/1033',
#    'dataset/PAS_imgs/positive/1025',
#    'dataset/PAS_imgs/positive/1018',
#    'dataset/PAS_imgs/positive/1030',
#    'dataset/PAS_imgs/positive/1024',
#    'dataset/PAS_imgs/negative/7048',
#    'dataset/PAS_imgs/negative/7074',
#    'dataset/PAS_imgs/negative/7128',
#    'dataset/PAS_imgs/negative/7114',
#    'dataset/PAS_imgs/negative/7100',
#    'dataset/PAS_imgs/negative/7101',
#    'dataset/PAS_imgs/negative/7115',
#    'dataset/PAS_imgs/negative/7129',
#    'dataset/PAS_imgs/negative/7075',
#    'dataset/PAS_imgs/negative/7061',
#    'dataset/PAS_imgs/negative/7049',
#    'dataset/PAS_imgs/negative/7063',
#    'dataset/PAS_imgs/negative/7088',
#    'dataset/PAS_imgs/negative/7103',
#    'dataset/PAS_imgs/negative/7117',
#    'dataset/PAS_imgs/negative/7102',
#    'dataset/PAS_imgs/negative/7089',
#    'dataset/PAS_imgs/negative/7076',
#    'dataset/PAS_imgs/negative/7072',
#    'dataset/PAS_imgs/negative/7066',
#    'dataset/PAS_imgs/negative/7106',
#    'dataset/PAS_imgs/negative/7112',
#    'dataset/PAS_imgs/negative/7113',
#    'dataset/PAS_imgs/negative/7098',
#    'dataset/PAS_imgs/negative/7067',
#    'dataset/PAS_imgs/negative/7073',
#    'dataset/PAS_imgs/negative/7065',
#    'dataset/PAS_imgs/negative/7071',
#    'dataset/PAS_imgs/negative/7059',
#    'dataset/PAS_imgs/negative/7105',
#    'dataset/PAS_imgs/negative/7104',
#    'dataset/PAS_imgs/negative/7110',
#    'dataset/PAS_imgs/negative/7070',
#    'dataset/PAS_imgs/negative/7064',
#    'dataset/PAS_imgs/negative/7003',
#    'dataset/PAS_imgs/negative/7017',
#    'dataset/PAS_imgs/negative/7016',
#    'dataset/PAS_imgs/negative/7002',
#    'dataset/PAS_imgs/negative/7028',
#    'dataset/PAS_imgs/negative/7014',
#    'dataset/PAS_imgs/negative/7029',
#    'dataset/PAS_imgs/negative/7011',
#    'dataset/PAS_imgs/negative/7005',
#    'dataset/PAS_imgs/negative/7039',
#    'dataset/PAS_imgs/negative/7038',
#    'dataset/PAS_imgs/negative/7004',
#    'dataset/PAS_imgs/negative/7006',
#    'dataset/PAS_imgs/negative/7013',
#    'dataset/PAS_imgs/negative/7007',
#    'dataset/PAS_imgs/negative/7022',
#    'dataset/PAS_imgs/negative/7036',
#    'dataset/PAS_imgs/negative/7037',
#    'dataset/PAS_imgs/negative/7023',
#    'dataset/PAS_imgs/negative/7009',
#    'dataset/PAS_imgs/negative/7035',
#    'dataset/PAS_imgs/negative/7021',
#    'dataset/PAS_imgs/negative/7020',
#    'dataset/PAS_imgs/negative/7034',
#    'dataset/PAS_imgs/negative/7008',
#    'dataset/PAS_imgs/negative/7030',
#    'dataset/PAS_imgs/negative/7024',
#    'dataset/PAS_imgs/negative/7018',
#    'dataset/PAS_imgs/negative/7019',
#    'dataset/PAS_imgs/negative/7025',
#    'dataset/PAS_imgs/negative/7031',
#    'dataset/PAS_imgs/negative/7027',
#    'dataset/PAS_imgs/negative/7033',
#    'dataset/PAS_imgs/negative/7026',
#    'dataset/PAS_imgs/negative/7069',
#    'dataset/PAS_imgs/negative/7041',
#    'dataset/PAS_imgs/negative/7082',
#    'dataset/PAS_imgs/negative/7096',
#    'dataset/PAS_imgs/negative/7109',
#    'dataset/PAS_imgs/negative/7135',
#    'dataset/PAS_imgs/negative/7121',
#    'dataset/PAS_imgs/negative/7120',
#    'dataset/PAS_imgs/negative/7134',
#    'dataset/PAS_imgs/negative/7083',
#    'dataset/PAS_imgs/negative/7054',
#    'dataset/PAS_imgs/negative/7068',
#    'dataset/PAS_imgs/negative/7056',
#    'dataset/PAS_imgs/negative/7095',
#    'dataset/PAS_imgs/negative/7081',
#    'dataset/PAS_imgs/negative/7122',
#    'dataset/PAS_imgs/negative/7123',
#    'dataset/PAS_imgs/negative/7080',
#    'dataset/PAS_imgs/negative/7094',
#    'dataset/PAS_imgs/negative/7043',
#    'dataset/PAS_imgs/negative/7057',
#    'dataset/PAS_imgs/negative/7053',
#    'dataset/PAS_imgs/negative/7047',
#    'dataset/PAS_imgs/negative/7090',
#    'dataset/PAS_imgs/negative/7084',
#    'dataset/PAS_imgs/negative/7126',
#    'dataset/PAS_imgs/negative/7046',
#    'dataset/PAS_imgs/negative/7052',
#    'dataset/PAS_imgs/negative/7044',
#    'dataset/PAS_imgs/negative/7078',
#    'dataset/PAS_imgs/negative/7087',
#    'dataset/PAS_imgs/negative/7093',
#    'dataset/PAS_imgs/negative/7130',
#    'dataset/PAS_imgs/negative/7119',
#    'dataset/PAS_imgs/negative/7125',
#    'dataset/PAS_imgs/negative/7131',
#    'dataset/PAS_imgs/negative/7092',
#    'dataset/PAS_imgs/negative/7086',
#    'dataset/PAS_imgs/negative/7079',
#    'dataset/PAS_imgs/negative/7045'],
#   ['dataset/PAS_imgs/positive/1017',
#    'dataset/PAS_imgs/positive/1038',
#    'dataset/PAS_imgs/positive/1039',
#    'dataset/PAS_imgs/positive/1011',
#    'dataset/PAS_imgs/positive/1052',
#    'dataset/PAS_imgs/positive/1023',
#    'dataset/PAS_imgs/positive/1027',
#    'dataset/PAS_imgs/positive/1031',
#    'dataset/PAS_imgs/positive/1019',
#    'dataset/PAS_imgs/negative/7060',
#    'dataset/PAS_imgs/negative/7077',
#    'dataset/PAS_imgs/negative/7116',
#    'dataset/PAS_imgs/negative/7062',
#    'dataset/PAS_imgs/negative/7099',
#    'dataset/PAS_imgs/negative/7107',
#    'dataset/PAS_imgs/negative/7111',
#    'dataset/PAS_imgs/negative/7058',
#    'dataset/PAS_imgs/negative/7001',
#    'dataset/PAS_imgs/negative/7015',
#    'dataset/PAS_imgs/negative/7010',
#    'dataset/PAS_imgs/negative/7012',
#    'dataset/PAS_imgs/negative/7032',
#    'dataset/PAS_imgs/negative/7055',
#    'dataset/PAS_imgs/negative/7108',
#    'dataset/PAS_imgs/negative/7097',
#    'dataset/PAS_imgs/negative/7040',
#    'dataset/PAS_imgs/negative/7042',
#    'dataset/PAS_imgs/negative/7136',
#    'dataset/PAS_imgs/negative/7133',
#    'dataset/PAS_imgs/negative/7132',
#    'dataset/PAS_imgs/negative/7085',
#    'dataset/PAS_imgs/negative/7091',
#    'dataset/PAS_imgs/negative/7050',
#    'dataset/PAS_imgs/negative/7124',
#    'dataset/PAS_imgs/negative/7118',
#    'dataset/PAS_imgs/negative/7051']),
#  (['dataset/PAS_imgs/positive/1015',
#    'dataset/PAS_imgs/positive/1028',
#    'dataset/PAS_imgs/positive/1016',
#    'dataset/PAS_imgs/positive/1017',
#    'dataset/PAS_imgs/positive/1013',
#    'dataset/PAS_imgs/positive/1012',
#    'dataset/PAS_imgs/positive/1010',
#    'dataset/PAS_imgs/positive/1038',
#    'dataset/PAS_imgs/positive/1039',
#    'dataset/PAS_imgs/positive/1011',
#    'dataset/PAS_imgs/positive/1049',
#    'dataset/PAS_imgs/positive/1043',
#    'dataset/PAS_imgs/positive/1057',
#    'dataset/PAS_imgs/positive/1054',
#    'dataset/PAS_imgs/positive/1055',
#    'dataset/PAS_imgs/positive/1051',
#    'dataset/PAS_imgs/positive/1045',
#    'dataset/PAS_imgs/positive/1044',
#    'dataset/PAS_imgs/positive/1050',
#    'dataset/PAS_imgs/positive/1046',
#    'dataset/PAS_imgs/positive/1052',
#    'dataset/PAS_imgs/positive/1053',
#    'dataset/PAS_imgs/positive/1047',
#    'dataset/PAS_imgs/positive/1034',
#    'dataset/PAS_imgs/positive/1035',
#    'dataset/PAS_imgs/positive/1021',
#    'dataset/PAS_imgs/positive/1037',
#    'dataset/PAS_imgs/positive/1023',
#    'dataset/PAS_imgs/positive/1022',
#    'dataset/PAS_imgs/positive/1036',
#    'dataset/PAS_imgs/positive/1026',
#    'dataset/PAS_imgs/positive/1027',
#    'dataset/PAS_imgs/positive/1025',
#    'dataset/PAS_imgs/positive/1031',
#    'dataset/PAS_imgs/positive/1019',
#    'dataset/PAS_imgs/positive/1018',
#    'dataset/PAS_imgs/positive/1030',
#    'dataset/PAS_imgs/positive/1024',
#    'dataset/PAS_imgs/negative/7060',
#    'dataset/PAS_imgs/negative/7114',
#    'dataset/PAS_imgs/negative/7101',
#    'dataset/PAS_imgs/negative/7115',
#    'dataset/PAS_imgs/negative/7129',
#    'dataset/PAS_imgs/negative/7075',
#    'dataset/PAS_imgs/negative/7061',
#    'dataset/PAS_imgs/negative/7049',
#    'dataset/PAS_imgs/negative/7077',
#    'dataset/PAS_imgs/negative/7063',
#    'dataset/PAS_imgs/negative/7088',
#    'dataset/PAS_imgs/negative/7103',
#    'dataset/PAS_imgs/negative/7117',
#    'dataset/PAS_imgs/negative/7116',
#    'dataset/PAS_imgs/negative/7089',
#    'dataset/PAS_imgs/negative/7062',
#    'dataset/PAS_imgs/negative/7076',
#    'dataset/PAS_imgs/negative/7072',
#    'dataset/PAS_imgs/negative/7099',
#    'dataset/PAS_imgs/negative/7106',
#    'dataset/PAS_imgs/negative/7112',
#    'dataset/PAS_imgs/negative/7113',
#    'dataset/PAS_imgs/negative/7107',
#    'dataset/PAS_imgs/negative/7098',
#    'dataset/PAS_imgs/negative/7067',
#    'dataset/PAS_imgs/negative/7073',
#    'dataset/PAS_imgs/negative/7065',
#    'dataset/PAS_imgs/negative/7071',
#    'dataset/PAS_imgs/negative/7059',
#    'dataset/PAS_imgs/negative/7111',
#    'dataset/PAS_imgs/negative/7104',
#    'dataset/PAS_imgs/negative/7110',
#    'dataset/PAS_imgs/negative/7058',
#    'dataset/PAS_imgs/negative/7070',
#    'dataset/PAS_imgs/negative/7064',
#    'dataset/PAS_imgs/negative/7003',
#    'dataset/PAS_imgs/negative/7016',
#    'dataset/PAS_imgs/negative/7002',
#    'dataset/PAS_imgs/negative/7014',
#    'dataset/PAS_imgs/negative/7001',
#    'dataset/PAS_imgs/negative/7015',
#    'dataset/PAS_imgs/negative/7029',
#    'dataset/PAS_imgs/negative/7011',
#    'dataset/PAS_imgs/negative/7005',
#    'dataset/PAS_imgs/negative/7039',
#    'dataset/PAS_imgs/negative/7038',
#    'dataset/PAS_imgs/negative/7004',
#    'dataset/PAS_imgs/negative/7010',
#    'dataset/PAS_imgs/negative/7006',
#    'dataset/PAS_imgs/negative/7012',
#    'dataset/PAS_imgs/negative/7013',
#    'dataset/PAS_imgs/negative/7007',
#    'dataset/PAS_imgs/negative/7022',
#    'dataset/PAS_imgs/negative/7036',
#    'dataset/PAS_imgs/negative/7037',
#    'dataset/PAS_imgs/negative/7023',
#    'dataset/PAS_imgs/negative/7021',
#    'dataset/PAS_imgs/negative/7020',
#    'dataset/PAS_imgs/negative/7034',
#    'dataset/PAS_imgs/negative/7008',
#    'dataset/PAS_imgs/negative/7030',
#    'dataset/PAS_imgs/negative/7019',
#    'dataset/PAS_imgs/negative/7025',
#    'dataset/PAS_imgs/negative/7031',
#    'dataset/PAS_imgs/negative/7027',
#    'dataset/PAS_imgs/negative/7033',
#    'dataset/PAS_imgs/negative/7032',
#    'dataset/PAS_imgs/negative/7026',
#    'dataset/PAS_imgs/negative/7069',
#    'dataset/PAS_imgs/negative/7055',
#    'dataset/PAS_imgs/negative/7082',
#    'dataset/PAS_imgs/negative/7096',
#    'dataset/PAS_imgs/negative/7121',
#    'dataset/PAS_imgs/negative/7134',
#    'dataset/PAS_imgs/negative/7108',
#    'dataset/PAS_imgs/negative/7097',
#    'dataset/PAS_imgs/negative/7083',
#    'dataset/PAS_imgs/negative/7054',
#    'dataset/PAS_imgs/negative/7040',
#    'dataset/PAS_imgs/negative/7056',
#    'dataset/PAS_imgs/negative/7042',
#    'dataset/PAS_imgs/negative/7095',
#    'dataset/PAS_imgs/negative/7081',
#    'dataset/PAS_imgs/negative/7136',
#    'dataset/PAS_imgs/negative/7123',
#    'dataset/PAS_imgs/negative/7080',
#    'dataset/PAS_imgs/negative/7043',
#    'dataset/PAS_imgs/negative/7057',
#    'dataset/PAS_imgs/negative/7053',
#    'dataset/PAS_imgs/negative/7047',
#    'dataset/PAS_imgs/negative/7084',
#    'dataset/PAS_imgs/negative/7133',
#    'dataset/PAS_imgs/negative/7132',
#    'dataset/PAS_imgs/negative/7126',
#    'dataset/PAS_imgs/negative/7085',
#    'dataset/PAS_imgs/negative/7091',
#    'dataset/PAS_imgs/negative/7044',
#    'dataset/PAS_imgs/negative/7050',
#    'dataset/PAS_imgs/negative/7087',
#    'dataset/PAS_imgs/negative/7093',
#    'dataset/PAS_imgs/negative/7124',
#    'dataset/PAS_imgs/negative/7118',
#    'dataset/PAS_imgs/negative/7119',
#    'dataset/PAS_imgs/negative/7125',
#    'dataset/PAS_imgs/negative/7092',
#    'dataset/PAS_imgs/negative/7086',
#    'dataset/PAS_imgs/negative/7051',
#    'dataset/PAS_imgs/negative/7045'],
#   ['dataset/PAS_imgs/positive/1029',
#    'dataset/PAS_imgs/positive/1048',
#    'dataset/PAS_imgs/positive/1056',
#    'dataset/PAS_imgs/positive/1040',
#    'dataset/PAS_imgs/positive/1041',
#    'dataset/PAS_imgs/positive/1020',
#    'dataset/PAS_imgs/positive/1009',
#    'dataset/PAS_imgs/positive/1032',
#    'dataset/PAS_imgs/positive/1033',
#    'dataset/PAS_imgs/negative/7048',
#    'dataset/PAS_imgs/negative/7074',
#    'dataset/PAS_imgs/negative/7128',
#    'dataset/PAS_imgs/negative/7100',
#    'dataset/PAS_imgs/negative/7102',
#    'dataset/PAS_imgs/negative/7066',
#    'dataset/PAS_imgs/negative/7105',
#    'dataset/PAS_imgs/negative/7017',
#    'dataset/PAS_imgs/negative/7028',
#    'dataset/PAS_imgs/negative/7009',
#    'dataset/PAS_imgs/negative/7035',
#    'dataset/PAS_imgs/negative/7024',
#    'dataset/PAS_imgs/negative/7018',
#    'dataset/PAS_imgs/negative/7041',
#    'dataset/PAS_imgs/negative/7109',
#    'dataset/PAS_imgs/negative/7135',
#    'dataset/PAS_imgs/negative/7120',
#    'dataset/PAS_imgs/negative/7068',
#    'dataset/PAS_imgs/negative/7122',
#    'dataset/PAS_imgs/negative/7094',
#    'dataset/PAS_imgs/negative/7090',
#    'dataset/PAS_imgs/negative/7046',
#    'dataset/PAS_imgs/negative/7052',
#    'dataset/PAS_imgs/negative/7078',
#    'dataset/PAS_imgs/negative/7130',
#    'dataset/PAS_imgs/negative/7131',
#    'dataset/PAS_imgs/negative/7079']),
#  (['dataset/PAS_imgs/positive/1029',
#    'dataset/PAS_imgs/positive/1028',
#    'dataset/PAS_imgs/positive/1016',
#    'dataset/PAS_imgs/positive/1017',
#    'dataset/PAS_imgs/positive/1013',
#    'dataset/PAS_imgs/positive/1012',
#    'dataset/PAS_imgs/positive/1010',
#    'dataset/PAS_imgs/positive/1038',
#    'dataset/PAS_imgs/positive/1039',
#    'dataset/PAS_imgs/positive/1011',
#    'dataset/PAS_imgs/positive/1049',
#    'dataset/PAS_imgs/positive/1048',
#    'dataset/PAS_imgs/positive/1057',
#    'dataset/PAS_imgs/positive/1056',
#    'dataset/PAS_imgs/positive/1040',
#    'dataset/PAS_imgs/positive/1041',
#    'dataset/PAS_imgs/positive/1055',
#    'dataset/PAS_imgs/positive/1045',
#    'dataset/PAS_imgs/positive/1044',
#    'dataset/PAS_imgs/positive/1052',
#    'dataset/PAS_imgs/positive/1053',
#    'dataset/PAS_imgs/positive/1047',
#    'dataset/PAS_imgs/positive/1020',
#    'dataset/PAS_imgs/positive/1034',
#    'dataset/PAS_imgs/positive/1035',
#    'dataset/PAS_imgs/positive/1021',
#    'dataset/PAS_imgs/positive/1009',
#    'dataset/PAS_imgs/positive/1037',
#    'dataset/PAS_imgs/positive/1023',
#    'dataset/PAS_imgs/positive/1022',
#    'dataset/PAS_imgs/positive/1036',
#    'dataset/PAS_imgs/positive/1032',
#    'dataset/PAS_imgs/positive/1026',
#    'dataset/PAS_imgs/positive/1027',
#    'dataset/PAS_imgs/positive/1033',
#    'dataset/PAS_imgs/positive/1031',
#    'dataset/PAS_imgs/positive/1019',
#    'dataset/PAS_imgs/positive/1018',
#    'dataset/PAS_imgs/negative/7048',
#    'dataset/PAS_imgs/negative/7060',
#    'dataset/PAS_imgs/negative/7074',
#    'dataset/PAS_imgs/negative/7128',
#    'dataset/PAS_imgs/negative/7114',
#    'dataset/PAS_imgs/negative/7100',
#    'dataset/PAS_imgs/negative/7115',
#    'dataset/PAS_imgs/negative/7075',
#    'dataset/PAS_imgs/negative/7061',
#    'dataset/PAS_imgs/negative/7077',
#    'dataset/PAS_imgs/negative/7063',
#    'dataset/PAS_imgs/negative/7103',
#    'dataset/PAS_imgs/negative/7116',
#    'dataset/PAS_imgs/negative/7102',
#    'dataset/PAS_imgs/negative/7062',
#    'dataset/PAS_imgs/negative/7076',
#    'dataset/PAS_imgs/negative/7072',
#    'dataset/PAS_imgs/negative/7066',
#    'dataset/PAS_imgs/negative/7099',
#    'dataset/PAS_imgs/negative/7106',
#    'dataset/PAS_imgs/negative/7112',
#    'dataset/PAS_imgs/negative/7107',
#    'dataset/PAS_imgs/negative/7073',
#    'dataset/PAS_imgs/negative/7065',
#    'dataset/PAS_imgs/negative/7071',
#    'dataset/PAS_imgs/negative/7059',
#    'dataset/PAS_imgs/negative/7111',
#    'dataset/PAS_imgs/negative/7105',
#    'dataset/PAS_imgs/negative/7104',
#    'dataset/PAS_imgs/negative/7058',
#    'dataset/PAS_imgs/negative/7070',
#    'dataset/PAS_imgs/negative/7064',
#    'dataset/PAS_imgs/negative/7017',
#    'dataset/PAS_imgs/negative/7016',
#    'dataset/PAS_imgs/negative/7002',
#    'dataset/PAS_imgs/negative/7028',
#    'dataset/PAS_imgs/negative/7001',
#    'dataset/PAS_imgs/negative/7015',
#    'dataset/PAS_imgs/negative/7029',
#    'dataset/PAS_imgs/negative/7005',
#    'dataset/PAS_imgs/negative/7038',
#    'dataset/PAS_imgs/negative/7004',
#    'dataset/PAS_imgs/negative/7010',
#    'dataset/PAS_imgs/negative/7012',
#    'dataset/PAS_imgs/negative/7013',
#    'dataset/PAS_imgs/negative/7007',
#    'dataset/PAS_imgs/negative/7022',
#    'dataset/PAS_imgs/negative/7037',
#    'dataset/PAS_imgs/negative/7023',
#    'dataset/PAS_imgs/negative/7009',
#    'dataset/PAS_imgs/negative/7035',
#    'dataset/PAS_imgs/negative/7034',
#    'dataset/PAS_imgs/negative/7008',
#    'dataset/PAS_imgs/negative/7030',
#    'dataset/PAS_imgs/negative/7024',
#    'dataset/PAS_imgs/negative/7018',
#    'dataset/PAS_imgs/negative/7019',
#    'dataset/PAS_imgs/negative/7025',
#    'dataset/PAS_imgs/negative/7027',
#    'dataset/PAS_imgs/negative/7033',
#    'dataset/PAS_imgs/negative/7032',
#    'dataset/PAS_imgs/negative/7026',
#    'dataset/PAS_imgs/negative/7069',
#    'dataset/PAS_imgs/negative/7041',
#    'dataset/PAS_imgs/negative/7055',
#    'dataset/PAS_imgs/negative/7082',
#    'dataset/PAS_imgs/negative/7096',
#    'dataset/PAS_imgs/negative/7109',
#    'dataset/PAS_imgs/negative/7135',
#    'dataset/PAS_imgs/negative/7121',
#    'dataset/PAS_imgs/negative/7120',
#    'dataset/PAS_imgs/negative/7134',
#    'dataset/PAS_imgs/negative/7108',
#    'dataset/PAS_imgs/negative/7097',
#    'dataset/PAS_imgs/negative/7083',
#    'dataset/PAS_imgs/negative/7040',
#    'dataset/PAS_imgs/negative/7068',
#    'dataset/PAS_imgs/negative/7056',
#    'dataset/PAS_imgs/negative/7042',
#    'dataset/PAS_imgs/negative/7081',
#    'dataset/PAS_imgs/negative/7122',
#    'dataset/PAS_imgs/negative/7136',
#    'dataset/PAS_imgs/negative/7123',
#    'dataset/PAS_imgs/negative/7080',
#    'dataset/PAS_imgs/negative/7094',
#    'dataset/PAS_imgs/negative/7043',
#    'dataset/PAS_imgs/negative/7057',
#    'dataset/PAS_imgs/negative/7090',
#    'dataset/PAS_imgs/negative/7133',
#    'dataset/PAS_imgs/negative/7132',
#    'dataset/PAS_imgs/negative/7085',
#    'dataset/PAS_imgs/negative/7091',
#    'dataset/PAS_imgs/negative/7046',
#    'dataset/PAS_imgs/negative/7052',
#    'dataset/PAS_imgs/negative/7044',
#    'dataset/PAS_imgs/negative/7050',
#    'dataset/PAS_imgs/negative/7078',
#    'dataset/PAS_imgs/negative/7087',
#    'dataset/PAS_imgs/negative/7093',
#    'dataset/PAS_imgs/negative/7130',
#    'dataset/PAS_imgs/negative/7124',
#    'dataset/PAS_imgs/negative/7118',
#    'dataset/PAS_imgs/negative/7119',
#    'dataset/PAS_imgs/negative/7125',
#    'dataset/PAS_imgs/negative/7131',
#    'dataset/PAS_imgs/negative/7092',
#    'dataset/PAS_imgs/negative/7079',
#    'dataset/PAS_imgs/negative/7051'],
#   ['dataset/PAS_imgs/positive/1015',
#    'dataset/PAS_imgs/positive/1043',
#    'dataset/PAS_imgs/positive/1054',
#    'dataset/PAS_imgs/positive/1051',
#    'dataset/PAS_imgs/positive/1050',
#    'dataset/PAS_imgs/positive/1046',
#    'dataset/PAS_imgs/positive/1025',
#    'dataset/PAS_imgs/positive/1030',
#    'dataset/PAS_imgs/positive/1024',
#    'dataset/PAS_imgs/negative/7101',
#    'dataset/PAS_imgs/negative/7129',
#    'dataset/PAS_imgs/negative/7049',
#    'dataset/PAS_imgs/negative/7088',
#    'dataset/PAS_imgs/negative/7117',
#    'dataset/PAS_imgs/negative/7089',
#    'dataset/PAS_imgs/negative/7113',
#    'dataset/PAS_imgs/negative/7098',
#    'dataset/PAS_imgs/negative/7067',
#    'dataset/PAS_imgs/negative/7110',
#    'dataset/PAS_imgs/negative/7003',
#    'dataset/PAS_imgs/negative/7014',
#    'dataset/PAS_imgs/negative/7011',
#    'dataset/PAS_imgs/negative/7039',
#    'dataset/PAS_imgs/negative/7006',
#    'dataset/PAS_imgs/negative/7036',
#    'dataset/PAS_imgs/negative/7021',
#    'dataset/PAS_imgs/negative/7020',
#    'dataset/PAS_imgs/negative/7031',
#    'dataset/PAS_imgs/negative/7054',
#    'dataset/PAS_imgs/negative/7095',
#    'dataset/PAS_imgs/negative/7053',
#    'dataset/PAS_imgs/negative/7047',
#    'dataset/PAS_imgs/negative/7084',
#    'dataset/PAS_imgs/negative/7126',
#    'dataset/PAS_imgs/negative/7086',
#    'dataset/PAS_imgs/negative/7045'])]
