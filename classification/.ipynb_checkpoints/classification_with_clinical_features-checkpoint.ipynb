# %% [markdown]
# ## **プログラム全体の流れ**
# - データローダの作成
# - ネットワークの定義
# - 誤差関数の定義
# - 学習ループの設計
# - モデルの学習
# - モデルの評価

# %% [markdown]
# # k-fold cross validationの仕組みを作っておく

# %% [markdown]
# - negative(165), positive(55)が混ざるようにしたい\
# →別々で分割して，結合する
# - 時期も混ざるようにしたい\
# →症例でシャッフルしてから分割する

# %%
import glob
from sklearn.model_selection import KFold

# %%
# 症例リストを取り出す
neg = glob.glob("dataset/PAS_imgs_train/negative/*")
pos = glob.glob("dataset/PAS_imgs_train/positive/*")

# %%
def make_kfold_set(k):
    k = k

    kf = KFold(n_splits=k, shuffle=True)

    neg_train_test_list = []
    pos_train_test_list = []
    
    neg = glob.glob("dataset/PAS_imgs_train/negative/*")
    pos = glob.glob("dataset/PAS_imgs_train/positive/*")

    for train_index, test_index in kf.split(neg):
        kth_train = []
        kth_test = []
        for i in train_index:
            kth_train.append(neg[i])
        for i in test_index:
            kth_test.append(neg[i])
        neg_train_test_list.append((kth_train, kth_test))

    for train_index, test_index in kf.split(pos):
        kth_train = []
        kth_test = []
        for i in train_index:
            kth_train.append(pos[i])
        for i in test_index:
            kth_test.append(pos[i])
        pos_train_test_list.append((kth_train, kth_test))


    posneg_train_test_list = []

    for i in range(k):
        train = pos_train_test_list[i][0] + neg_train_test_list[i][0]
        test = pos_train_test_list[i][1] + neg_train_test_list[i][1]
        posneg_train_test_list.append((train, test))

    
    return posneg_train_test_list

# %% [markdown]
# <div style="text-align: center;">
# <IMG SRC="https://drive.google.com/uc?id=1rWgWkMT0LLv17p21C2NQMjPh_bkJ_Fcu" width="70%">
# <br>
# 図5　ミニバッチ学習のおさらい
# </div>

# %%
import numpy as np
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision import transforms
import torch.optim as optim
from torch.nn import CrossEntropyLoss
from torchvision import models, transforms
import torch.nn as nn
import torch.nn.functional as F
import pydicom
import matplotlib.pyplot as plt
from PIL import Image

import cv2

import pandas as pd
from sklearn.metrics import roc_curve, roc_auc_score

def describe_ROC(predict_memo, label_memo, csv_path, roc_path):
    predicts = pd.Series(torch.cat(predict_memo).softmax(dim=1).cpu().detach().numpy()[:,1])
    labels = pd.Series(torch.cat(label_memo).cpu().detach().numpy())
    df = pd.concat([predicts, labels], axis=1)
    df = df.rename(columns={0:"pred", 1:"label"})
    df.to_csv(csv_path, index=False)
    fpr, tpr, thresholds = roc_curve(labels, predicts)
    auc = roc_auc_score(labels, predicts)
    plt.figure()
    plt.plot(fpr, tpr, label="ROC (AUC=" + str(round(auc, 4)) + ")" )
    plt.xlabel("False positive rate")
    plt.ylabel("True positive rate")
    plt.legend()
    plt.savefig(roc_path)
    plt.clf()
    return

class CNNwithClinicalFeature(nn.Module):
    def __init__(self):
        super(CNNwithClinicalFeature, self).__init__()
        
        # ネットワークを定義
        self.ResNet = models.resnet50(pretrained=False)
        self.ResNet.load_state_dict(torch.load("resnet50-19c8e357.pth"), strict=False)
        self.ResNet.conv1 = nn.Conv2d(1, 64, 7, 2, 3, bias=False)
        self.ResNet.fc = nn.Linear(2048, 100, bias=True)
        self.clinical_layer = nn.Linear(107, 2, bias=True)
        
    def forward(self, x, clinical_features):
        x = self.ResNet(x)
        # xとclinical_featuresをconcat(107次元になるはず)
        #print(x.shape, clinical_features.shape)
        concatted_features = torch.cat([x, clinical_features], axis=1)
        x = self.clinical_layer(concatted_features)
        return x
        

k = 5
k_train_test_set = make_kfold_set(k)

# データセットクラスを作る
class PASDataset(Dataset):
    # trainとtestが分割されているリストを受け取る
    def __init__(self, train_test, mode):
        super().__init__()
        # 呼び出された瞬間に起こってほしいこと（コンストラクタ）
        if mode == "train":
            self.patients = train_test[0]
        elif mode == "test":
            self.patients = train_test[1]
        else:
            raise Exception('Error!')
        self.imgs = self.patient2imgs(self.patients)
        
        # 臨床情報の読み込み
        self.clinical_df = pd.read_csv("dataset/PAS_table.csv")
        self.clinical_df = self.clinical_df.drop("PAS", axis=1)
        
    def __len__(self):
        # データがいくつあるのかを数える
        return len(self.imgs)
    
    
    def __getitem__(self, index):
        # データが取り出される瞬間にどのような形であってほしいかを定義する
        
        image_path = self.imgs[index]
        img = pydicom.read_file(image_path)
        img = np.int32(img.pixel_array)
        
        img = img / 2048.0
        
        mask_path = image_path.replace("raw", "label").replace("dcm", "png")
        mask = np.array(Image.open(mask_path))
        img = self.mask_imgs(img, mask)
        
        # 胎盤の重心を中心とした大きめの正方形で切り取る
        img = self.crop_img(img, mask)
        
        img = np.expand_dims(img, 0) # 1チャンネルであることを明示する
        # 水増し
        #img = self.transforms(img)
        
        if "positive" in image_path:
            label = 1
        else:
            label = 0
        
        ID = int(image_path.split("/")[-3])
        clinical_feature = self._fetch_clinical_features(ID).flatten()
        #print(clinical_feature)
        return img, label, image_path, clinical_feature
    
    def patient2imgs(self, patient_list):
        imgs_list = []
        for patient in patient_list:
            img_paths = glob.glob(patient + "/raw/*")
            for img in img_paths:
                if "dcm" in img:
                    imgs_list.append(img)
        return imgs_list
    
    def mask_imgs(self, img, mask):
        masked_img = img
        zeros = mask == 0
        masked_img[zeros] = 0
        return masked_img
    
    def crop_img(self, img, mask):
        # maskから重心を計算
        nLabels, labelImages, data, center = cv2.connectedComponentsWithStats(mask)
        # 重心を中心に，imgを切り取り
        max_index = np.argmin(data[:,4])
        object_width = data[max_index][2]
        object_height = data[max_index][3]
        object_center = (data[max_index][0]+(object_width/2), data[max_index][1]+(object_height/2))
        hen = int(max(object_width, object_height)/2)
        cropped_img = Image.fromarray(img).crop((object_center[0]-hen, object_center[1]-hen, object_center[0]+hen, object_center[1]+hen)).resize((256,256))
        cropped_img = np.array(cropped_img)
        return cropped_img
    
    def _fetch_clinical_features(self, ID):
        features = torch.Tensor(np.array(self.clinical_df[self.clinical_df["ID"] == ID].iloc[:, 1:8]))
        return features

#transforms = transfomrs.Compose([
    
#])     



epochs = 30 #ミニバッチのサンプリングが一巡 = 1 epoch
loss_min = 100000 # validation_lossが小さくなった場合にのみモデルを保存しておくためのメモ

# k回の繰り返し
for fold in range(k):
    print("-------------------fold " + str(fold+1) + " --------------------")
    # データローダの作成
    pas_train = PASDataset(k_train_test_set[fold], "train")
    pas_test = PASDataset(k_train_test_set[fold], "test")
    train_loader = DataLoader(pas_train, batch_size=24, shuffle=True)
    test_loader = DataLoader(pas_test, batch_size=24)
    
    # モデルの定義
    model = CNNwithClinicalFeature()

    # CPUを使う場合は，下記を削除する
    model = model.to("cuda")
    # optimizer（勾配降下法のアルゴリズム）の準備
    optimizer = optim.Adam(model.parameters(), lr=0.0001)

    # 誤差関数の定義
    criterion = CrossEntropyLoss()
    
    
    
    # 学習ループ
    train_loss_list = [] # epoch毎のtrain_lossを保存しておくための入れ物
    val_loss_list = [] # epoch毎のvalidation_lossを保存しておくための入れ物

    min_loss_mean = 100000
    
    # ここからループ開始
    for epoch in range(epochs):

        train_loss_add = 0 # 1エポック分の誤差を累積しておくための変数
        train_acc_add = 0

        model.train() #学習モードであることを明示

        for i, data in enumerate(train_loader):

            x, t, path, clinical_feature = data # ①データの読み込み
            # CPU環境で動かす際は，下記2行を削除する
            x = x.float().to("cuda")
            t = t.to("cuda")
            clinical_feature = clinical_feature.to("cuda")
            
            predict = model(x, clinical_feature) # 臨床データも追加する場合
            #print(predict, t)

            loss = criterion(predict, t) # ③誤差の計算
            _, preds = torch.max(predict, 1)
            #print(preds)

            model.zero_grad()# 誤差逆伝播法のための準備
            loss.backward() # ④誤差逆伝播法による誤差の計算

            optimizer.step() # ⑤勾配を用いてパラメータを更新

            train_loss_add += loss.data * train_loader.batch_size # あとで平均を計算するために，誤差を累積しておく
            train_acc_add += torch.sum(preds == t.data)

        train_loss_mean = train_loss_add / len(pas_train) # 1epochでの誤差の平均を計算
        train_acc_mean = train_acc_add / float(len(pas_train))

        print("epoch" + str(epoch+1))
        print("train_loss:" + str(train_loss_mean), "train_acc:" + str(train_acc_mean))
        train_loss_list.append(train_loss_mean.cpu())# 1epoch毎の平均を格納しておく

        # validation
        model.eval() # 評価モード（学習を行わない）であることを明示

        pred_memo = [] # ROC描画用
        label_memo = [] # ROC描画用
        
        val_loss_add = 0
        val_acc_add = 0
        for i, data in enumerate(test_loader):

            x, t, path, clinical_feature = data

            # CPU環境で動かす際は，下記2行を削除する
            x = x.float().to("cuda")
            t = t.to("cuda")
            clinical_feature = clinical_feature.to("cuda")

            predict = model(x, clinical_feature) # 臨床データも追加する場合
            _, preds = torch.max(predict, 1)

            pred_memo.append(predict)
            label_memo.append(t)

            loss = criterion(predict, t) # 誤差の計算
            val_loss_add += loss.data * test_loader.batch_size
            val_acc_add += torch.sum(preds == t.data)

        val_loss_mean = val_loss_add / len(pas_test)
        val_acc_mean = val_acc_add / float(len(pas_test))

        print("val_loss:" + str(val_loss_mean), "val_acc:" + str(val_acc_mean))
        val_loss_list.append(val_loss_mean.cpu())

        if val_loss_mean < min_loss_mean:
            describe_ROC(pred_memo, label_memo, csv_path="result/with_pretrain/pred_label_fold_" + str(fold+1) + ".csv", roc_path="result/with_pretrain/roc_fold_" + str(fold+1) + ".png")
            torch.save(model.state_dict(), "model/best.model")
            min_loss_mean = val_loss_mean
            
    # 各foldで，学習曲線を描画
    # 各foldで，testにおけるpredsとlabelをcsvに保存（全epochが終わった時点）
    plt.figure()
    plt.plot(train_loss_list, label="train")
    plt.plot(val_loss_list, label="val")
    plt.legend()
    plt.savefig("result/with_pretrain/training_curve_fold_" + str(fold + 1) + ".png")
    plt.clf()
# Out:
# -------------------fold 1 --------------------
# epoch1
# train_loss:tensor(0.3424, device='cuda:0') train_acc:tensor(0.8719, device='cuda:0')
# val_loss:tensor(0.5285, device='cuda:0') val_acc:tensor(0.7943, device='cuda:0')
# epoch2
# train_loss:tensor(0.1955, device='cuda:0') train_acc:tensor(0.9108, device='cuda:0')
# val_loss:tensor(0.7832, device='cuda:0') val_acc:tensor(0.8000, device='cuda:0')
# epoch3
# train_loss:tensor(0.1122, device='cuda:0') train_acc:tensor(0.9568, device='cuda:0')
# val_loss:tensor(0.6524, device='cuda:0') val_acc:tensor(0.7771, device='cuda:0')
# epoch4
# train_loss:tensor(0.1233, device='cuda:0') train_acc:tensor(0.9540, device='cuda:0')
# val_loss:tensor(0.6175, device='cuda:0') val_acc:tensor(0.7886, device='cuda:0')
# epoch5
# train_loss:tensor(0.0714, device='cuda:0') train_acc:tensor(0.9683, device='cuda:0')
# val_loss:tensor(0.7916, device='cuda:0') val_acc:tensor(0.8057, device='cuda:0')
# epoch6
# train_loss:tensor(0.0672, device='cuda:0') train_acc:tensor(0.9784, device='cuda:0')
# val_loss:tensor(1.0349, device='cuda:0') val_acc:tensor(0.7943, device='cuda:0')
# epoch7
# train_loss:tensor(0.0425, device='cuda:0') train_acc:tensor(0.9842, device='cuda:0')
# val_loss:tensor(1.0342, device='cuda:0') val_acc:tensor(0.7886, device='cuda:0')
# epoch8
# train_loss:tensor(0.0491, device='cuda:0') train_acc:tensor(0.9827, device='cuda:0')
# val_loss:tensor(0.7113, device='cuda:0') val_acc:tensor(0.7943, device='cuda:0')
# epoch9
# train_loss:tensor(0.0206, device='cuda:0') train_acc:tensor(0.9957, device='cuda:0')
# val_loss:tensor(0.8171, device='cuda:0') val_acc:tensor(0.8229, device='cuda:0')
# epoch10
# train_loss:tensor(0.0134, device='cuda:0') train_acc:tensor(0.9971, device='cuda:0')
# val_loss:tensor(0.8658, device='cuda:0') val_acc:tensor(0.8286, device='cuda:0')
# epoch11
# train_loss:tensor(0.0411, device='cuda:0') train_acc:tensor(0.9842, device='cuda:0')
# val_loss:tensor(1.2452, device='cuda:0') val_acc:tensor(0.7200, device='cuda:0')
# epoch12
# train_loss:tensor(0.0644, device='cuda:0') train_acc:tensor(0.9784, device='cuda:0')
# val_loss:tensor(0.6733, device='cuda:0') val_acc:tensor(0.8571, device='cuda:0')
# epoch13
# train_loss:tensor(0.0625, device='cuda:0') train_acc:tensor(0.9799, device='cuda:0')
# val_loss:tensor(0.7413, device='cuda:0') val_acc:tensor(0.8000, device='cuda:0')
# epoch14
# train_loss:tensor(0.0169, device='cuda:0') train_acc:tensor(0.9957, device='cuda:0')
# val_loss:tensor(0.6393, device='cuda:0') val_acc:tensor(0.8629, device='cuda:0')
# epoch15
# train_loss:tensor(0.0162, device='cuda:0') train_acc:tensor(0.9928, device='cuda:0')
# val_loss:tensor(0.8133, device='cuda:0') val_acc:tensor(0.8400, device='cuda:0')
device='cuda:0') train_acc:tensor(1., device='cuda:0')
# val_loss:tensor(1.1284, device='cuda:0') val_acc:tensor(0.8057, device='cuda:0')
# epoch26
# train_loss:tensor(0.0034, device='cuda:0') train_acc:tensor(1., device='cuda:0')
# val_loss:tensor(1.4156, device='cuda:0') val_acc:tensor(0.8229, device='cuda:0')
# epoch27
# train_loss:tensor(0.0040, device='cuda:0') train_acc:tensor(0.9986, device='cuda:0')
# val_loss:tensor(1.4860, device='cuda:0') val_acc:tensor(0.8229, device='cuda:0')
# epoch28
# train_loss:tensor(0.0047, device='cuda:0') train_acc:tensor(1., device='cuda:0')
# val_loss:tensor(1.3953, device='cuda:0') val_acc:tensor(0.8000, device='cuda:0')
# epoch29
# train_loss:tensor(0.0031, device='cuda:0') train_acc:tensor(1., device='cuda:0')
# val_loss:tensor(1.2166, device='cuda:0') val_acc:tensor(0.8457, device='cuda:0')
# epoch30
# train_loss:tensor(0.0018, device='cuda:0') train_acc:tensor(1., device='cuda:0')
# val_loss:tensor(0.9874, device='cuda:0') val_acc:tensor(0.8629, device='cuda:0')
# -------------------fold 3 --------------------
# epoch1
# train_loss:tensor(0.7020, device='cuda:0') train_acc:tensor(0.7367, device='cuda:0')
# val_loss:tensor(0.7349, device='cuda:0') val_acc:tensor(0.8000, device='cuda:0')
# epoch2
# train_loss:tensor(0.1826, device='cuda:0') train_acc:tensor(0.9367, device='cuda:0')
# val_loss:tensor(0.6590, device='cuda:0') val_acc:tensor(0.8229, device='cuda:0')
# epoch3
# train_loss:tensor(0.1223, device='cuda:0') train_acc:tensor(0.9669, device='cuda:0')
# val_loss:tensor(0.8047, device='cuda:0') val_acc:tensor(0.7371, device='cuda:0')
# epoch4
# train_loss:tensor(0.0508, device='cuda:0') train_acc:tensor(0.9871, device='cuda:0')
# val_loss:tensor(0.5081, device='cuda:0') val_acc:tensor(0.8800, device='cuda:0')
# epoch5
# train_loss:tensor(0.0433, device='cuda:0') train_acc:tensor(0.9914, device='cuda:0')
# val_loss:tensor(0.5947, device='cuda:0') val_acc:tensor(0.8514, device='cuda:0')
# epoch6
# train_loss:tensor(0.0257, device='cuda:0') train_acc:tensor(0.9928, device='cuda:0')
# val_loss:tensor(0.7047, device='cuda:0') val_acc:tensor(0.8743, device='cuda:0')
# epoch7
# train_loss:tensor(0.0216, device='cuda:0') train_acc:tensor(0.9899, device='cuda:0')
# val_loss:tensor(0.5779, device='cuda:0') val_acc:tensor(0.8629, device='cuda:0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d6d585a1d975> in <module>
#     196             clinical_feature = clinical_feature.to("cuda")
#     197
# --> 198             predict = model(x, clinical_feature) # 臨床データも追加する場合
#     199             #print(predict, t)
#     200
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# <ipython-input-5-d6d585a1d975> in forward(self, x, clinical_features)
#      47
#      48     def forward(self, x, clinical_features):
# ---> 49         x = self.ResNet(x)
#      50         # xとclinical_featuresをconcat(107次元になるはず)
#      51         #print(x.shape, clinical_features.shape)
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/torchvision/models/resnet.py in forward(self, x)
#     218
#     219     def forward(self, x):
# --> 220         return self._forward_impl(x)
#     221
#     222
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/torchvision/models/resnet.py in _forward_impl(self, x)
#     206         x = self.maxpool(x)
#     207
# --> 208         x = self.layer1(x)
#     209         x = self.layer2(x)
#     210         x = self.layer3(x)
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      98     def forward(self, input):
#      99         for module in self:
# --> 100             input = module(input)
#     101         return input
#     102
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/torchvision/models/resnet.py in forward(self, x)
#     114
#     115         if self.downsample is not None:
# --> 116             identity = self.downsample(x)
#     117
#     118         out += identity
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      98     def forward(self, input):
#      99         for module in self:
# --> 100             input = module(input)
#     101         return input
#     102
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/torch/nn/modules/batchnorm.py in forward(self, input)
#      95             # TODO: if statement only here to tell the jit to skip emitting this when it is None
#      96             if self.num_batches_tracked is not None:
# ---> 97                 self.num_batches_tracked = self.num_batches_tracked + 1
#      98                 if self.momentum is None:  # use cumulative moving average
#      99                     exponential_average_factor = 1.0 / float(self.num_batches_tracked)
#
# KeyboardInterrupt:

# %%
model = CNNwithClinicalFeature()
model.to("cuda")

# %%
x = torch.zeros(12, 100)
x = x.to("cuda")
features = torch.zeros(12, 7)
features = features.to("cuda")

# %%
torch.cat([x, features], axis=1).shape
# Out:
# torch.Size([12, 107])

# %%
model.forward(x, features)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-d469210cb65a> in <module>
# ----> 1 model.forward(x, features)
#
# <ipython-input-12-fa8dc893b71b> in forward(self, x, clinical_features)
#      47
#      48     def forward(self, x, clinical_features):
# ---> 49         x = self.ResNet(x)
#      50         # xとclinical_featuresをconcat(107次元になるはず)
#      51         concatted_features = torch.cat([x, clinical_features], axis=0)
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/torchvision/models/resnet.py in forward(self, x)
#     218
#     219     def forward(self, x):
# --> 220         return self._forward_impl(x)
#     221
#     222
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/torchvision/models/resnet.py in _forward_impl(self, x)
#     201     def _forward_impl(self, x):
#     202         # See note [TorchScript super()]
# --> 203         x = self.conv1(x)
#     204         x = self.bn1(x)
#     205         x = self.relu(x)
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     351
#     352     def forward(self, input):
# --> 353         return self._conv_forward(input, self.weight)
#     354
#     355 class Conv3d(_ConvNd):
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight)
#     348                             _pair(0), self.dilation, self.groups)
#     349         return F.conv2d(input, weight, self.bias, self.stride,
# --> 350                         self.padding, self.dilation, self.groups)
#     351
#     352     def forward(self, input):
#
# RuntimeError: Expected 4-dimensional input for 4-dimensional weight [64, 1, 7, 7], but got 2-dimensional input of size [12, 100] instead

# %%
import pandas as pd
from sklearn.metrics import roc_curve, roc_auc_score

def describe_ROC(predict_memo, label_memo, csv_path, roc_path):
    predicts = pd.Series(torch.concat(predict_memo).softmax(dim=1).cpu().detach().numpy()[:,1])
    labels = pd.Series(torch.concat(label_memo).cpu().detach().numpy())
    df = pd.concat([predicts, labels], axis=1)
    df = df.rename(columns={0:"pred", 1:"label"})
    df.to_csv(csv_path, index=False)
    fpr, tpr, thresholds = roc_curve(labels, predicts)
    auc = roc_auc_score(labels, predicts)
    plt.figure()
    plt.plot(fpr, tpr, label="ROC (AUC=" + str(round(auc, 4)) + ")" )
    plt.xlabel("False positive rate")
    plt.ylabel("True positive rate")
    plt.legend()
    plt.savefig(roc_path)
    return

# %%
csv_path = "result/test.csv"
roc_path = "result/test.png"
describe_ROC(pred_memo, label_memo, csv_path, roc_path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-ad891a3bea5a> in <module>
#       1 csv_path = "result/test.csv"
#       2 roc_path = "result/test.png"
# ----> 3 describe_ROC(pred_memo, label_memo, csv_path, roc_path)
#
# <ipython-input-5-e840a3b0f3a2> in describe_ROC(predict_memo, label_memo, csv_path, roc_path)
#       3
#       4 def describe_ROC(predict_memo, label_memo, csv_path, roc_path):
# ----> 5     predicts = pd.Series(torch.concat(predict_memo).softmax(dim=1).cpu().detach().numpy()[:,1])
#       6     labels = pd.Series(torch.concat(label_memo).cpu().detach().numpy())
#       7     df = pd.concat([predicts, labels], axis=1)
#
# AttributeError: module 'torch' has no attribute 'concat'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /takaya_workspace/tohoku/ai_lab/harigai/classification_takaya _20221125.ipynb Cell 11 in <module>
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bmarianna-container/takaya_workspace/tohoku/ai_lab/harigai/classification_takaya%20_20221125.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> pred_memo
#
# NameError: name 'pred_memo' is not defined

# %%
pred_memo[0][5].softmax(dim=0)
# Out:
# tensor([7.0688e-04, 9.9929e-01], device='cuda:0', grad_fn=<SoftmaxBackward0>)

# %%
Image.fromarray(np.uint8(x[0][0].cpu() * 2048))

# %%
list(predict.cpu().detach().numpy())
# Out:
# [array([-0.08238305, -0.14279255], dtype=float32),
#  array([ 2.5953586, -2.4516199], dtype=float32)]

# %%
k = 5
kfold_list = make_kfold_set(k)

for i in range(5):
    PAS = PASDataset(ith_fold)
    predict = model(PAS)

# %%
dcm = pydicom.read_file("dataset/PAS_imgs/positive/1029/raw/0.dcm")

# %%
len(pas_train)
# Out:
# 676

# %%
model.conv1 = nn.Conv2d(1, 64, 7, 2, 3)

# %%
_, preds = torch.max(predict, 1)

# %%
preds
# Out:
# tensor([0, 0, 0, 0, 0], device='cuda:0')

# %%
test_loader.batch_size
# Out:
# 5

# %%
img_path = "dataset/PAS_imgs/positive/1029/raw/0.jpg"

# %%
mask_path = img_path.replace("raw", "label").replace("jpg", "png")

# %%
from PIL import Image
img = np.array(Image.open(img_path))
mask = np.array(Image.open(mask_path))

# %%
zeros = mask == 0

# %%
Image.open(img_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x7FF05B09CA90>

# %%
Image.fromarray(img).resize((256, 256))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FF05864EB50>

# %%
nLabels, labelImages, data, center = cv2.connectedComponentsWithStats(mask)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-02115f55e0d0> in <module>
# ----> 1 nLabels, labelImages, data, center = cv2.connectedComponentsWithStats(mask)
#
# NameError: name 'cv2' is not defined

# %%
mask = np.array(Image.open(mask_path))
nLabels, labelImages, data, center = cv2.connectedComponentsWithStats(mask)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <module>
# ----> 1 mask = np.array(Image.open(mask_path))
#       2 nLabels, labelImages, data, center = cv2.connectedComponentsWithStats(mask)
#
# NameError: name 'mask_path' is not defined

# %%
import cv2

# %%
Image.open(mask_path).crop((199, 171, 199+95, 171+199))
# Out:
# <PIL.Image.Image image mode=L size=95x199 at 0x7F4DF58B2908>

# %%
data
# Out:
# array([[     0,      0,    512,    512, 255234],
#        [   199,    171,     95,    199,   6910]], dtype=int32)

# %%
data[:,4]
# Out:
# array([255234,   6910], dtype=int32)

# %%
max_index = np.argmin(data[:,4])
object_width = data[max_index][2]
object_height = data[max_index][3]
object_center = (data[max_index][0]+(object_width/2), data[max_index][1]+(object_height/2))
hen = int(max(object_width, object_height)/2)
Image.open(mask_path).crop((object_center[0]-hen, object_center[1]-hen, object_center[0]+hen, object_center[1]+hen))
# Out:
# <PIL.Image.Image image mode=L size=198x198 at 0x7F4DF236FBA8>

# %%
max(1,2)
# Out:
# 2

# %%
a = torch.Tensor(mask)
Image.fromarray(np.uint8(a.numpy()))
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F266C4F5340>

# %%
a.max()
# Out:
# tensor(255.)

# %%
# IDを指定したら，対応するclinical featuresを取ってくる関数
def fetch_clinical_features(ID):
    df = pd.read_csv("dataset/PAS_table.csv")
    df = df.drop("PAS", axis=1)
    features = torch.Tensor(np.array(df[df["ID"] == ID].iloc[:, 1:8]))
    return features

# %%
df = pd.read_csv("dataset/PAS_table.csv")

# %%
df = df.drop("PAS", axis=1)

# %%
torch.Tensor(np.array(df[df["ID"] == 1001].iloc[:, 1:8])).flatten().shape
# Out:
# torch.Size([7])

# %%
image_path = "dataset/PAS_imgs/positive/1026/raw/0.dcm"

# %%
# Out:
# '1026'
